# %% [markdown]
# # 📘 Industrial Machine Predictive Maintenance
#
# ## Data Understanding
#
# ### Project Objective
#
# The objective of this notebook is to understand the dataset before performing any preprocessing or model building. This includes exploring the dataset structure, identifying feature types, checking data quality, and understanding the target variable for the regression task.

# %% [markdown]
# # 1. Import Required Libraries
#
# In this section, we import the required Python libraries that will be used throughout the notebook for data loading and analysis.

# %%
import pandas as pd

import numpy as np

# %% [markdown]
# # 2. Load the Dataset
#
# Load the industrial machine predictive maintenance dataset into a Pandas DataFrame for further exploration.

# %%
df=pd.read_csv("./data/predictive_maintenance.csv")

# %% [markdown]
# # 3. Display the First Five Records
#
# Display the first five rows of the dataset to get an initial understanding of the available features and data format.

# %%
df.head()
# Out:
#              timestamp  machine_id machine_type  vibration_rms  \
# 0  2024-01-01 00:00:00           1          CNC           0.81
# 1  2024-01-01 00:03:00           1          CNC           0.75
# 2  2024-01-01 00:21:00           1          CNC           0.71
# 3  2024-01-01 00:45:00           1          CNC           0.76
# 4  2024-01-01 00:54:00           1          CNC           0.88
#
#    temperature_motor  current_phase_avg  pressure_level    rpm operating_mode  \
# 0              49.51               5.10            23.6  860.9           idle
# 1              40.58               5.30            23.6  899.6           idle
# 2              49.70                NaN            21.3  862.7           idle
# 3              43.04               4.79            22.6  870.4           idle
# 4              41.39               4.44            22.2  881.9           idle
#
#    hours_since_maintenance  ambient_temp  rul_hours  failure_within_24h  \
# ...

# %% [markdown]
# # 4. Check Dataset Dimensions
#
# Determine the total number of rows and columns present in the dataset.

# %%
df.shape
# Out:
# (24042, 15)

# %% [markdown]
# # 5. Display Feature Names
#
# List all feature names available in the dataset to understand the input variables and identify the target variable.

# %%
df.columns
# Out:
# Index(['timestamp', 'machine_id', 'machine_type', 'vibration_rms',
#        'temperature_motor', 'current_phase_avg', 'pressure_level', 'rpm',
#        'operating_mode', 'hours_since_maintenance', 'ambient_temp',
#        'rul_hours', 'failure_within_24h', 'failure_type',
#        'estimated_repair_cost'],
#       dtype='object')

# %%
df['machine_type'].value_counts()
# Out:
# machine_type
# Pump           6114
# Robotic Arm    6003
# Compressor     5988
# CNC            5937
# Name: count, dtype: int64

# %% [markdown]
# # 6. Explore Dataset Information
#
# Inspect the dataset to understand:
#
# - Number of entries
# - Data types of each feature
# - Memory usage
# - Missing values (if any)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24042 entries, 0 to 24041
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   timestamp                24042 non-null  object
#  1   machine_id               24042 non-null  int64
#  2   machine_type             24042 non-null  object
#  3   vibration_rms            23042 non-null  float64
#  4   temperature_motor        23208 non-null  float64
#  5   current_phase_avg        23311 non-null  float64
#  6   pressure_level           23118 non-null  float64
#  7   rpm                      23509 non-null  float64
#  8   operating_mode           24042 non-null  object
#  9   hours_since_maintenance  24042 non-null  float64
#  10  ambient_temp             24042 non-null  float64
#  11  rul_hours                24042 non-null  float64
#  12  failure_within_24h       24042 non-null  int64
#  13  failure_type             24042 non-null  object
# ...

# %%
print("Rows :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows : 24042
# Columns : 15

# %%
df.columns.tolist()
# Out:
# ['timestamp',
#  'machine_id',
#  'machine_type',
#  'vibration_rms',
#  'temperature_motor',
#  'current_phase_avg',
#  'pressure_level',
#  'rpm',
#  'operating_mode',
#  'hours_since_maintenance',
#  'ambient_temp',
#  'rul_hours',
#  'failure_within_24h',
#  'failure_type',
#  'estimated_repair_cost']

# %% [markdown]
# # 7. Check Missing Values
#
# Identify whether any feature contains missing values that need to be handled during preprocessing.

# %%
df.isnull().sum()
# Out:
# timestamp                     0
# machine_id                    0
# machine_type                  0
# vibration_rms              1000
# temperature_motor           834
# current_phase_avg           731
# pressure_level              924
# rpm                         533
# operating_mode                0
# hours_since_maintenance       0
# ambient_temp                  0
# rul_hours                     0
# failure_within_24h            0
# failure_type                  0
# estimated_repair_cost         0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 4022

# %% [markdown]
# # 8. Check Duplicate Records
#
# Verify whether duplicate rows exist in the dataset.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 9. Generate Statistical Summary
#
# Generate descriptive statistics for all numerical features, including:
#
# - Mean
# - Standard Deviation
# - Minimum
# - Maximum
# - Quartiles

# %%
df.describe().T
# Out:
#                            count         mean          std     min     25%  \
# machine_id               24042.0    10.505033     5.746455    1.00    6.00
# vibration_rms            23042.0     1.623667     1.081061    0.35    0.82
# temperature_motor        23208.0    51.404295    12.519279   28.00   42.61
# current_phase_avg        23311.0     8.823829     5.366391    2.20    4.63
# pressure_level           23118.0    59.012233    38.723271   10.10   22.70
# rpm                      23509.0  1144.849317   912.670971  124.10  489.40
# hours_since_maintenance  24042.0   172.630624   150.722469    0.00   42.87
# ambient_temp             24042.0    12.996398     2.883994    8.00   10.50
# rul_hours                24042.0    27.812510    26.393801    0.50    0.50
# failure_within_24h       24042.0     0.148074     0.355181    0.00    0.00
# estimated_repair_cost    24042.0   608.870144  1566.793887    0.00    0.00
#
#                             50%        75%      max
# ...

# %% [markdown]
# # 10. Display Random Samples
#
# Display a few random records to ensure that the dataset is loaded correctly and to inspect different observations.

# %%
df.sample(5)
# Out:
#                  timestamp  machine_id machine_type  vibration_rms  \
# 15752  2024-01-02 16:16:00          14   Compressor           2.14
# 5329   2024-01-08 11:11:08           5          CNC           2.17
# 10097  2024-01-06 00:59:00           9         Pump            NaN
# 22235  2024-01-07 08:16:19          19  Robotic Arm           0.91
# 2417   2024-01-01 20:33:00           3          CNC           2.20
#
#        temperature_motor  current_phase_avg  pressure_level     rpm  \
# 15752              50.99              14.74           118.5  1795.5
# 5329               62.50              14.86            62.5  3019.2
# 10097              42.22               3.52            15.2   557.8
# 22235              45.99               5.73            47.8   352.2
# 2417               59.41              13.18            75.3  2964.8
#
#       operating_mode  hours_since_maintenance  ambient_temp  rul_hours  \
# 15752         normal                   289.13          14.3      46.15
# ...

# %% [markdown]
# # 11. Analyze the Target Variable
#
# The target variable for this project is **estimated_repair_cost**.
#
# This section provides a statistical overview of the target variable to understand its distribution.

# %%
target = "estimated_repair_cost"

print(df[target].describe())
# Out:
# count    24042.000000
# mean       608.870144
# std       1566.793887
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       7995.000000
# Name: estimated_repair_cost, dtype: float64

# %% [markdown]
# # 12. Identify Numerical and Categorical Features
#
# Separate the dataset into numerical and categorical features.
#
# This helps in selecting appropriate preprocessing techniques during feature engineering.

# %%
numerical_columns = df.select_dtypes(include=["int64", "float64"]).columns.tolist()
categorical_columns = df.select_dtypes(include=["object"]).columns.tolist()

print(f"Numerical Features ({len(numerical_columns)}):")
print(numerical_columns)

print("\nCategorical Features ({})".format(len(categorical_columns)))
print(categorical_columns)
# Out:
# Numerical Features (11):
# ['machine_id', 'vibration_rms', 'temperature_motor', 'current_phase_avg', 'pressure_level', 'rpm', 'hours_since_maintenance', 'ambient_temp', 'rul_hours', 'failure_within_24h', 'estimated_repair_cost']
#
# Categorical Features (4)
# ['timestamp', 'machine_type', 'operating_mode', 'failure_type']

# %% [markdown]
# # Key Observations
#
# After completing the initial exploration, summarize the important findings from the dataset.
#
# Example:
#
# - Dataset contains 24042 rows and 15 columns.
# - Target variable is **estimated_repair_cost**.
# - The dataset contains both numerical and categorical features.
# - Missing values: 4022
# - Duplicate records: 0
# - Dataset is suitable for regression analysis.
